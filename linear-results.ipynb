# %%
import polars as pl

# R2 for Linear model with all features
scores = {
    "spruce": [0.2741, 0.2707, 0.2702, 0.2708, 0.2743],
    "pine": [0.3076, 0.3073, 0.3064, 0.3108, 0.3064],
    "beech": [0.3529, 0.3501, 0.3482, 0.3507, 0.3494],
    "oak": [0.2946, 0.2832, 0.3052, 0.3101, 0.2788],
}

pl.from_dict(scores).describe(percentiles=None)
# Out:
# shape: (6, 5)
# ┌────────────┬──────────┬──────────┬──────────┬──────────┐
# │ statistic  ┆ spruce   ┆ pine     ┆ beech    ┆ oak      │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ str        ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞════════════╪══════════╪══════════╪══════════╪══════════╡
# │ count      ┆ 5.0      ┆ 5.0      ┆ 5.0      ┆ 5.0      │
# │ null_count ┆ 0.0      ┆ 0.0      ┆ 0.0      ┆ 0.0      │
# │ mean       ┆ 0.27202  ┆ 0.3077   ┆ 0.35026  ┆ 0.29438  │
# │ std        ┆ 0.002004 ┆ 0.001814 ┆ 0.001744 ┆ 0.013527 │
# │ min        ┆ 0.2702   ┆ 0.3064   ┆ 0.3482   ┆ 0.2788   │
# │ max        ┆ 0.2743   ┆ 0.3108   ┆ 0.3529   ┆ 0.3101   │
# └────────────┴──────────┴──────────┴──────────┴──────────┘

# %%
# R2 for Linear model with defoliation features
scores = {
    "spruce": [0.0853, 0.0793, 0.0799, 0.0857, 0.0852],
    "pine": [0.0489, 0.0537, 0.0536, 0.0532, 0.0492],
    "beech": [0.0321, 0.0334, 0.0315, 0.0337, 0.0313],
    "oak": [0.0465, 0.0426, 0.0171, 0.0388, 0.0402],
}

pl.from_dict(scores).describe(percentiles=None)
# Out:
# shape: (6, 5)
# ┌────────────┬──────────┬──────────┬──────────┬──────────┐
# │ statistic  ┆ spruce   ┆ pine     ┆ beech    ┆ oak      │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ str        ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞════════════╪══════════╪══════════╪══════════╪══════════╡
# │ count      ┆ 5.0      ┆ 5.0      ┆ 5.0      ┆ 5.0      │
# │ null_count ┆ 0.0      ┆ 0.0      ┆ 0.0      ┆ 0.0      │
# │ mean       ┆ 0.08308  ┆ 0.05172  ┆ 0.0324   ┆ 0.03704  │
# │ std        ┆ 0.003189 ┆ 0.002447 ┆ 0.001095 ┆ 0.011523 │
# │ min        ┆ 0.0793   ┆ 0.0489   ┆ 0.0313   ┆ 0.0171   │
# │ max        ┆ 0.0857   ┆ 0.0537   ┆ 0.0337   ┆ 0.0465   │
# └────────────┴──────────┴──────────┴──────────┴──────────┘
