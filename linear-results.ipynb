# %%
import polars as pl

# R2 for Linear model with all features
scores = {
    "spruce": [0.2741, 0.2707, 0.2702, 0.2708, 0.2743],
    "pine": [0.3076, 0.3073, 0.3064, 0.3108, 0.3064],
    "beech": [0.3529, 0.3501, 0.3482, 0.3507, 0.3494],
    "oak": [0.2946, 0.2832, 0.3052, 0.3101, 0.2788],
}

pl.from_dict(scores).describe(percentiles=None)

# %%
# R2 for Linear model with tree-level features
scores = {
    "spruce": [0.0981, 0.1024, 0.1016, 0.0998, 0.1007],
    "pine": [0.0969, 0.0995, 0.1000, 0.1001, 0.1002],
    "beech": [0.1605, 0.1658, 0.1598, 0.1368, 0.1651],
    "oak": [0.0859, 0.0792, 0.0762, 0.0679, 0.0724],
}

pl.from_dict(scores).describe(percentiles=None)

# %%
# R2 for Linear model with plot-level features
scores = {
    "spruce": [0.268, 0.2682, 0.2662, 0.2678, 0.2689],
    "pine": [0.3169, 0.3145, 0.3231, 0.3150, 0.3136],
    "beech": [0.2787, 0.2757, 0.2733, 0.2731, 0.2749],
    "oak": [0.2592, 0.2645, 0.2535, 0.2776, 0.2560],
}

pl.from_dict(scores).describe(percentiles=None)

# %%
# R2 for Linear model with all features (group by plot_id)
scores = {
    "spruce": [-0.1307, -0.2635, -0.3023, -0.4888, -0.1800],
    "pine": [-0.2113, -0.0971, -0.9301, -0.2845, -0.2273],
    "beech": [0.0705, 0.1057, 0.1021, 0.1235, 0.0361],
    "oak": [-0.594, -0.4459, -0.3545, -2.3172, -0.2780],
}

pl.from_dict(scores).describe(percentiles=None)

# %%
# R2 for Linear model with tree-level features (group by plot_id)
scores = {
    "spruce": [0.1381, 0.1408, 0.1356, 0.1426, 0.1409],
    "pine": [0.0373, 0.0433, 0.0470, 0.0479, 0.0512],
    "beech": [0.2293, 0.1773, 0.1784, 0.1871, 0.1810],
    "oak": [-0.0690, -0.1031, -0.0639, -0.1988, -0.0879],
}

pl.from_dict(scores).describe(percentiles=None)
